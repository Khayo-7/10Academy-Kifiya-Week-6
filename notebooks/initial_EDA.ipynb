# %%
# %load_ext autoreload

# %autoreload 2

# %%
import os
import sys
sys.path.append('..')

from scripts.data_utils.loaders import *
from scripts.data_utils.cleaner import *
from scripts.utils.visualization import *
from scripts.data_utils.preprocess import *
from scripts.data_utils.feature_engineering import *

# %%
RESOURCEPATH = os.path.join('..', 'resources')
DATAPATH = os.path.join(RESOURCEPATH, 'data')
processed_output_dir = os.path.join(DATAPATH, 'processed')
raw_data_path = os.path.join(DATAPATH, 'raw')
plot_output_dir = os.path.join('..', 'screenshots', 'plots')
os.makedirs(plot_output_dir, exist_ok=True)

# %%
filename = 'data.csv'
file_path = os.path.join(raw_data_path, filename)
data_csv = load_data(file_path)
data_csv.shape
# Out:
# 2025-01-26 10:48:36 - INFO - Loading data from ..\resources\data\raw\data.csv
# 2025-01-26 10:48:36 - INFO - Loading data from ..\resources\data\raw\data.csv
# 2025-01-26 10:48:36 - INFO - Loading data from ..\resources\data\raw\data.csv
# 2025-01-26 10:48:36 - INFO - Loading data from ..\resources\data\raw\data.csv
# 2025-01-26 10:48:36 - INFO - Loading data from ..\resources\data\raw\data.csv
# 2025-01-26 10:48:36 - INFO - Successfully loaded data from ..\resources\data\raw\data.csv
# 2025-01-26 10:48:36 - INFO - Successfully loaded data from ..\resources\data\raw\data.csv
# 2025-01-26 10:48:36 - INFO - Successfully loaded data from ..\resources\data\raw\data.csv
# 2025-01-26 10:48:36 - INFO - Successfully loaded data from ..\resources\data\raw\data.csv
# 2025-01-26 10:48:36 - INFO - Successfully loaded data from ..\resources\data\raw\data.csv
# (95662, 16)

# %%
filename2 = 'data.xlsx'
file_path2 = os.path.join(raw_data_path, filename2)
data_xlsx = load_data(file_path2, sheet_name='data')
data_xlsx.shape
# Out:
# 2025-01-26 10:48:36 - INFO - Loading data from ..\resources\data\raw\data.xlsx
# 2025-01-26 10:48:36 - INFO - Loading data from ..\resources\data\raw\data.xlsx
# 2025-01-26 10:48:36 - INFO - Loading data from ..\resources\data\raw\data.xlsx
# 2025-01-26 10:48:36 - INFO - Loading data from ..\resources\data\raw\data.xlsx
# 2025-01-26 10:48:36 - INFO - Loading data from ..\resources\data\raw\data.xlsx
# 2025-01-26 10:49:08 - INFO - Successfully loaded data from ..\resources\data\raw\data.xlsx
# 2025-01-26 10:49:08 - INFO - Successfully loaded data from ..\resources\data\raw\data.xlsx
# 2025-01-26 10:49:08 - INFO - Successfully loaded data from ..\resources\data\raw\data.xlsx
# 2025-01-26 10:49:08 - INFO - Successfully loaded data from ..\resources\data\raw\data.xlsx
# 2025-01-26 10:49:08 - INFO - Successfully loaded data from ..\resources\data\raw\data.xlsx
# (95662, 18)

# %%
data = data_xlsx

# %%
summarize_data(data)
# Out:
# 2025-01-26 10:49:08 - INFO -
# --- Data Summary ---
# 2025-01-26 10:49:08 - INFO -
# --- Data Summary ---
# 2025-01-26 10:49:08 - INFO -
# --- Data Summary ---
# 2025-01-26 10:49:08 - INFO -
# --- Data Summary ---
# 2025-01-26 10:49:08 - INFO -
# --- Data Summary ---
# 2025-01-26 10:49:09 - INFO -                         count unique                   top   freq  \
# TransactionId           95662  95662   TransactionId_76871      1
# BatchId                 95662  94809         BatchId_67019     28
# AccountId               95660   3633        AccountId_4841  30893
# SubscriptionId          95662   3627   SubscriptionId_3829  32630
# CustomerId              95662   3742       CustomerId_7343   4091
# CurrencyCode            95662      1                   UGX  95662
# CountryCode           95660.0    NaN                   NaN    NaN
# ProviderId              95660      6          ProviderId_4  38189
# ProductId               95662     23           ProductId_6  32635
# ProductCategory         95662      9    financial_services  45405
# ChannelId               95662      4           ChannelId_3  56935
# Amount                95662.0    NaN                   NaN    NaN
# Value                 95659.0    NaN                   NaN    NaN
# TransactionStartTime    95661  94555  2018-12-24T16:30:13Z     17
# PricingStrategy       95659.0    NaN                   NaN    NaN
# FraudResult           95662.0    NaN                   NaN    NaN
# Unnamed: 16                16     16         January542024      1
# Unnamed: 17                12      7           202454March      4
#
#                              mean            std        min    25%     50%  \
# TransactionId                 NaN            NaN        NaN    NaN     NaN
# BatchId                       NaN            NaN        NaN    NaN     NaN
# AccountId                     NaN            NaN        NaN    NaN     NaN
# SubscriptionId                NaN            NaN        NaN    NaN     NaN
# CustomerId                    NaN            NaN        NaN    NaN     NaN
# CurrencyCode                  NaN            NaN        NaN    NaN     NaN
# CountryCode                 256.0            0.0      256.0  256.0   256.0
# ProviderId                    NaN            NaN        NaN    NaN     NaN
# ProductId                     NaN            NaN        NaN    NaN     NaN
# ProductCategory               NaN            NaN        NaN    NaN     NaN
# ChannelId                     NaN            NaN        NaN    NaN     NaN
# Amount                6718.071528  123306.788665 -1000000.0  -50.0  1000.0
# Value                  9900.64041  123124.006009        2.0  275.0  1000.0
# TransactionStartTime          NaN            NaN        NaN    NaN     NaN
# PricingStrategy          2.255899       0.732849        0.0    2.0     2.0
# FraudResult              0.002018       0.044872        0.0    0.0     0.0
# Unnamed: 16                   NaN            NaN        NaN    NaN     NaN
# Unnamed: 17                   NaN            NaN        NaN    NaN     NaN
#
#                          75%        max
# TransactionId            NaN        NaN
# BatchId                  NaN        NaN
# AccountId                NaN        NaN
# SubscriptionId           NaN        NaN
# CustomerId               NaN        NaN
# CurrencyCode             NaN        NaN
# CountryCode            256.0      256.0
# ProviderId               NaN        NaN
# ProductId                NaN        NaN
# ProductCategory          NaN        NaN
# ChannelId                NaN        NaN
# Amount                2800.0  9880000.0
# Value                 5000.0  9880000.0
# TransactionStartTime     NaN        NaN
# PricingStrategy          2.0        4.0
# FraudResult              0.0        1.0
# Unnamed: 16              NaN        NaN
# Unnamed: 17              NaN        NaN
# 2025-01-26 10:49:09 - INFO -                         count unique                   top   freq  \
# TransactionId           95662  95662   TransactionId_76871      1
# BatchId                 95662  94809         BatchId_67019     28
# AccountId               95660   3633        AccountId_4841  30893
# SubscriptionId          95662   3627   SubscriptionId_3829  32630
# CustomerId              95662   3742       CustomerId_7343   4091
# CurrencyCode            95662      1                   UGX  95662
# CountryCode           95660.0    NaN                   NaN    NaN
# ProviderId              95660      6          ProviderId_4  38189
# ProductId               95662     23           ProductId_6  32635
# ProductCategory         95662      9    financial_services  45405
# ChannelId               95662      4           ChannelId_3  56935
# Amount                95662.0    NaN                   NaN    NaN
# Value                 95659.0    NaN                   NaN    NaN
# TransactionStartTime    95661  94555  2018-12-24T16:30:13Z     17
# PricingStrategy       95659.0    NaN                   NaN    NaN
# FraudResult           95662.0    NaN                   NaN    NaN
# Unnamed: 16                16     16         January542024      1
# Unnamed: 17                12      7           202454March      4
#
#                              mean            std        min    25%     50%  \
# TransactionId                 NaN            NaN        NaN    NaN     NaN
# BatchId                       NaN            NaN        NaN    NaN     NaN
# AccountId                     NaN            NaN        NaN    NaN     NaN
# SubscriptionId                NaN            NaN        NaN    NaN     NaN
# CustomerId                    NaN            NaN        NaN    NaN     NaN
# CurrencyCode                  NaN            NaN        NaN    NaN     NaN
# CountryCode                 256.0            0.0      256.0  256.0   256.0
# ProviderId                    NaN            NaN        NaN    NaN     NaN
# ProductId                     NaN            NaN        NaN    NaN     NaN
# ProductCategory               NaN            NaN        NaN    NaN     NaN
# ChannelId                     NaN            NaN        NaN    NaN     NaN
# Amount                6718.071528  123306.788665 -1000000.0  -50.0  1000.0
# Value                  9900.64041  123124.006009        2.0  275.0  1000.0
# TransactionStartTime          NaN            NaN        NaN    NaN     NaN
# PricingStrategy          2.255899       0.732849        0.0    2.0     2.0
# FraudResult              0.002018       0.044872        0.0    0.0     0.0
# Unnamed: 16                   NaN            NaN        NaN    NaN     NaN
# Unnamed: 17                   NaN            NaN        NaN    NaN     NaN
#
#                          75%        max
# TransactionId            NaN        NaN
# BatchId                  NaN        NaN
# AccountId                NaN        NaN
# SubscriptionId           NaN        NaN
# CustomerId               NaN        NaN
# CurrencyCode             NaN        NaN
# CountryCode            256.0      256.0
# ProviderId               NaN        NaN
# ProductId                NaN        NaN
# ProductCategory          NaN        NaN
# ChannelId                NaN        NaN
# Amount                2800.0  9880000.0
# Value                 5000.0  9880000.0
# TransactionStartTime     NaN        NaN
# PricingStrategy          2.0        4.0
# FraudResult              0.0        1.0
# Unnamed: 16              NaN        NaN
# Unnamed: 17              NaN        NaN
# 2025-01-26 10:49:09 - INFO -                         count unique                   top   freq  \
# TransactionId           95662  95662   TransactionId_76871      1
# BatchId                 95662  94809         BatchId_67019     28
# AccountId               95660   3633        AccountId_4841  30893
# SubscriptionId          95662   3627   SubscriptionId_3829  32630
# CustomerId              95662   3742       CustomerId_7343   4091
# CurrencyCode            95662      1                   UGX  95662
# CountryCode           95660.0    NaN                   NaN    NaN
# ProviderId              95660      6          ProviderId_4  38189
# ProductId               95662     23           ProductId_6  32635
# ProductCategory         95662      9    financial_services  45405
# ChannelId               95662      4           ChannelId_3  56935
# Amount                95662.0    NaN                   NaN    NaN
# Value                 95659.0    NaN                   NaN    NaN
# TransactionStartTime    95661  94555  2018-12-24T16:30:13Z     17
# PricingStrategy       95659.0    NaN                   NaN    NaN
# FraudResult           95662.0    NaN                   NaN    NaN
# Unnamed: 16                16     16         January542024      1
# Unnamed: 17                12      7           202454March      4
#
#                              mean            std        min    25%     50%  \
# TransactionId                 NaN            NaN        NaN    NaN     NaN
# BatchId                       NaN            NaN        NaN    NaN     NaN
# AccountId                     NaN            NaN        NaN    NaN     NaN
# SubscriptionId                NaN            NaN        NaN    NaN     NaN
# CustomerId                    NaN            NaN        NaN    NaN     NaN
# CurrencyCode                  NaN            NaN        NaN    NaN     NaN
# CountryCode                 256.0            0.0      256.0  256.0   256.0
# ProviderId                    NaN            NaN        NaN    NaN     NaN
# ProductId                     NaN            NaN        NaN    NaN     NaN
# ProductCategory               NaN            NaN        NaN    NaN     NaN
# ChannelId                     NaN            NaN        NaN    NaN     NaN
# Amount                6718.071528  123306.788665 -1000000.0  -50.0  1000.0
# Value                  9900.64041  123124.006009        2.0  275.0  1000.0
# TransactionStartTime          NaN            NaN        NaN    NaN     NaN
# PricingStrategy          2.255899       0.732849        0.0    2.0     2.0
# FraudResult              0.002018       0.044872        0.0    0.0     0.0
# Unnamed: 16                   NaN            NaN        NaN    NaN     NaN
# Unnamed: 17                   NaN            NaN        NaN    NaN     NaN
#
#                          75%        max
# TransactionId            NaN        NaN
# BatchId                  NaN        NaN
# AccountId                NaN        NaN
# SubscriptionId           NaN        NaN
# CustomerId               NaN        NaN
# CurrencyCode             NaN        NaN
# CountryCode            256.0      256.0
# ProviderId               NaN        NaN
# ProductId                NaN        NaN
# ProductCategory          NaN        NaN
# ChannelId                NaN        NaN
# Amount                2800.0  9880000.0
# Value                 5000.0  9880000.0
# TransactionStartTime     NaN        NaN
# PricingStrategy          2.0        4.0
# FraudResult              0.0        1.0
# Unnamed: 16              NaN        NaN
# Unnamed: 17              NaN        NaN
# 2025-01-26 10:49:09 - INFO -                         count unique                   top   freq  \
# TransactionId           95662  95662   TransactionId_76871      1
# BatchId                 95662  94809         BatchId_67019     28
# AccountId               95660   3633        AccountId_4841  30893
# SubscriptionId          95662   3627   SubscriptionId_3829  32630
# CustomerId              95662   3742       CustomerId_7343   4091
# CurrencyCode            95662      1                   UGX  95662
# CountryCode           95660.0    NaN                   NaN    NaN
# ProviderId              95660      6          ProviderId_4  38189
# ProductId               95662     23           ProductId_6  32635
# ProductCategory         95662      9    financial_services  45405
# ChannelId               95662      4           ChannelId_3  56935
# Amount                95662.0    NaN                   NaN    NaN
# Value                 95659.0    NaN                   NaN    NaN
# TransactionStartTime    95661  94555  2018-12-24T16:30:13Z     17
# PricingStrategy       95659.0    NaN                   NaN    NaN
# FraudResult           95662.0    NaN                   NaN    NaN
# Unnamed: 16                16     16         January542024      1
# Unnamed: 17                12      7           202454March      4
#
#                              mean            std        min    25%     50%  \
# TransactionId                 NaN            NaN        NaN    NaN     NaN
# BatchId                       NaN            NaN        NaN    NaN     NaN
# AccountId                     NaN            NaN        NaN    NaN     NaN
# SubscriptionId                NaN            NaN        NaN    NaN     NaN
# CustomerId                    NaN            NaN        NaN    NaN     NaN
# CurrencyCode                  NaN            NaN        NaN    NaN     NaN
# CountryCode                 256.0            0.0      256.0  256.0   256.0
# ProviderId                    NaN            NaN        NaN    NaN     NaN
# ProductId                     NaN            NaN        NaN    NaN     NaN
# ProductCategory               NaN            NaN        NaN    NaN     NaN
# ChannelId                     NaN            NaN        NaN    NaN     NaN
# Amount                6718.071528  123306.788665 -1000000.0  -50.0  1000.0
# Value                  9900.64041  123124.006009        2.0  275.0  1000.0
# TransactionStartTime          NaN            NaN        NaN    NaN     NaN
# PricingStrategy          2.255899       0.732849        0.0    2.0     2.0
# FraudResult              0.002018       0.044872        0.0    0.0     0.0
# Unnamed: 16                   NaN            NaN        NaN    NaN     NaN
# Unnamed: 17                   NaN            NaN        NaN    NaN     NaN
#
#                          75%        max
# TransactionId            NaN        NaN
# BatchId                  NaN        NaN
# AccountId                NaN        NaN
# SubscriptionId           NaN        NaN
# CustomerId               NaN        NaN
# CurrencyCode             NaN        NaN
# CountryCode            256.0      256.0
# ProviderId               NaN        NaN
# ProductId                NaN        NaN
# ProductCategory          NaN        NaN
# ChannelId                NaN        NaN
# Amount                2800.0  9880000.0
# Value                 5000.0  9880000.0
# TransactionStartTime     NaN        NaN
# PricingStrategy          2.0        4.0
# FraudResult              0.0        1.0
# Unnamed: 16              NaN        NaN
# Unnamed: 17              NaN        NaN
# 2025-01-26 10:49:09 - INFO -                         count unique                   top   freq  \
# TransactionId           95662  95662   TransactionId_76871      1
# BatchId                 95662  94809         BatchId_67019     28
# AccountId               95660   3633        AccountId_4841  30893
# SubscriptionId          95662   3627   SubscriptionId_3829  32630
# CustomerId              95662   3742       CustomerId_7343   4091
# CurrencyCode            95662      1                   UGX  95662
# CountryCode           95660.0    NaN                   NaN    NaN
# ProviderId              95660      6          ProviderId_4  38189
# ProductId               95662     23           ProductId_6  32635
# ProductCategory         95662      9    financial_services  45405
# ChannelId               95662      4           ChannelId_3  56935
# Amount                95662.0    NaN                   NaN    NaN
# Value                 95659.0    NaN                   NaN    NaN
# TransactionStartTime    95661  94555  2018-12-24T16:30:13Z     17
# PricingStrategy       95659.0    NaN                   NaN    NaN
# FraudResult           95662.0    NaN                   NaN    NaN
# Unnamed: 16                16     16         January542024      1
# Unnamed: 17                12      7           202454March      4
#
#                              mean            std        min    25%     50%  \
# TransactionId                 NaN            NaN        NaN    NaN     NaN
# BatchId                       NaN            NaN        NaN    NaN     NaN
# AccountId                     NaN            NaN        NaN    NaN     NaN
# SubscriptionId                NaN            NaN        NaN    NaN     NaN
# CustomerId                    NaN            NaN        NaN    NaN     NaN
# CurrencyCode                  NaN            NaN        NaN    NaN     NaN
# CountryCode                 256.0            0.0      256.0  256.0   256.0
# ProviderId                    NaN            NaN        NaN    NaN     NaN
# ProductId                     NaN            NaN        NaN    NaN     NaN
# ProductCategory               NaN            NaN        NaN    NaN     NaN
# ChannelId                     NaN            NaN        NaN    NaN     NaN
# Amount                6718.071528  123306.788665 -1000000.0  -50.0  1000.0
# Value                  9900.64041  123124.006009        2.0  275.0  1000.0
# TransactionStartTime          NaN            NaN        NaN    NaN     NaN
# PricingStrategy          2.255899       0.732849        0.0    2.0     2.0
# FraudResult              0.002018       0.044872        0.0    0.0     0.0
# Unnamed: 16                   NaN            NaN        NaN    NaN     NaN
# Unnamed: 17                   NaN            NaN        NaN    NaN     NaN
#
#                          75%        max
# TransactionId            NaN        NaN
# BatchId                  NaN        NaN
# AccountId                NaN        NaN
# SubscriptionId           NaN        NaN
# CustomerId               NaN        NaN
# CurrencyCode             NaN        NaN
# CountryCode            256.0      256.0
# ProviderId               NaN        NaN
# ProductId                NaN        NaN
# ProductCategory          NaN        NaN
# ChannelId                NaN        NaN
# Amount                2800.0  9880000.0
# Value                 5000.0  9880000.0
# TransactionStartTime     NaN        NaN
# PricingStrategy          2.0        4.0
# FraudResult              0.0        1.0
# Unnamed: 16              NaN        NaN
# Unnamed: 17              NaN        NaN
# 2025-01-26 10:49:09 - INFO -
# --- Data Info ---
# 2025-01-26 10:49:09 - INFO -
# --- Data Info ---
# 2025-01-26 10:49:09 - INFO -
# --- Data Info ---
# 2025-01-26 10:49:09 - INFO -
# --- Data Info ---
# 2025-01-26 10:49:09 - INFO -
# --- Data Info ---
# 2025-01-26 10:49:09 - INFO - None
# 2025-01-26 10:49:09 - INFO - None
# 2025-01-26 10:49:09 - INFO - None
# 2025-01-26 10:49:09 - INFO - None
# 2025-01-26 10:49:09 - INFO - None
# 2025-01-26 10:49:09 - INFO -
# --- Total columns with Missing Values ---
# 2025-01-26 10:49:09 - INFO -
# --- Total columns with Missing Values ---
# 2025-01-26 10:49:09 - INFO -
# --- Total columns with Missing Values ---
# 2025-01-26 10:49:09 - INFO -
# --- Total columns with Missing Values ---
# 2025-01-26 10:49:09 - INFO -
# --- Total columns with Missing Values ---
# 2025-01-26 10:49:09 - INFO - 8
# 2025-01-26 10:49:09 - INFO - 8
# 2025-01-26 10:49:09 - INFO - 8
# 2025-01-26 10:49:09 - INFO - 8
# 2025-01-26 10:49:09 - INFO - 8
# 2025-01-26 10:49:09 - INFO -
# --- Missing Values ---
# 2025-01-26 10:49:09 - INFO -
# --- Missing Values ---
# 2025-01-26 10:49:09 - INFO -
# --- Missing Values ---
# 2025-01-26 10:49:09 - INFO -
# --- Missing Values ---
# 2025-01-26 10:49:09 - INFO -
# --- Missing Values ---
# 2025-01-26 10:49:09 - INFO - TransactionId               0
# BatchId                     0
# AccountId                   2
# SubscriptionId              0
# CustomerId                  0
# CurrencyCode                0
# CountryCode                 2
# ProviderId                  2
# ProductId                   0
# ProductCategory             0
# ChannelId                   0
# Amount                      0
# Value                       3
# TransactionStartTime        1
# PricingStrategy             3
# FraudResult                 0
# Unnamed: 16             95646
# Unnamed: 17             95650
# dtype: int64
# 2025-01-26 10:49:09 - INFO - TransactionId               0
# BatchId                     0
# AccountId                   2
# SubscriptionId              0
# CustomerId                  0
# CurrencyCode                0
# CountryCode                 2
# ProviderId                  2
# ProductId                   0
# ProductCategory             0
# ChannelId                   0
# Amount                      0
# Value                       3
# TransactionStartTime        1
# PricingStrategy             3
# FraudResult                 0
# Unnamed: 16             95646
# Unnamed: 17             95650
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95662 entries, 0 to 95661
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TransactionId         95662 non-null  object
#  1   BatchId               95662 non-null  object
#  2   AccountId             95660 non-null  object
#  3   SubscriptionId        95662 non-null  object
#  4   CustomerId            95662 non-null  object
#  5   CurrencyCode          95662 non-null  object
#  6   CountryCode           95660 non-null  float64
#  7   ProviderId            95660 non-null  object
#  8   ProductId             95662 non-null  object
#  9   ProductCategory       95662 non-null  object
#  10  ChannelId             95662 non-null  object
#  11  Amount                95662 non-null  float64
#  12  Value                 95659 non-null  float64
#  13  TransactionStartTime  95661 non-null  object
#  14  PricingStrategy       95659 non-null  float64
#  15  FraudResult           95662 non-null  int64
#  16  Unnamed: 16           16 non-null     object
#  17  Unnamed: 17           12 non-null     object
# dtypes: float64(4), int64(1), object(13)
# memory usage: 13.1+ MB
# 2025-01-26 10:49:09 - INFO - TransactionId               0
# BatchId                     0
# AccountId                   2
# SubscriptionId              0
# CustomerId                  0
# CurrencyCode                0
# CountryCode                 2
# ProviderId                  2
# ProductId                   0
# ProductCategory             0
# ChannelId                   0
# Amount                      0
# Value                       3
# TransactionStartTime        1
# PricingStrategy             3
# FraudResult                 0
# Unnamed: 16             95646
# Unnamed: 17             95650
# dtype: int64
# 2025-01-26 10:49:09 - INFO - TransactionId               0
# BatchId                     0
# AccountId                   2
# SubscriptionId              0
# CustomerId                  0
# CurrencyCode                0
# CountryCode                 2
# ProviderId                  2
# ProductId                   0
# ProductCategory             0
# ChannelId                   0
# Amount                      0
# Value                       3
# TransactionStartTime        1
# PricingStrategy             3
# FraudResult                 0
# Unnamed: 16             95646
# Unnamed: 17             95650
# dtype: int64
# 2025-01-26 10:49:09 - INFO - TransactionId               0
# BatchId                     0
# AccountId                   2
# SubscriptionId              0
# CustomerId                  0
# CurrencyCode                0
# CountryCode                 2
# ProviderId                  2
# ProductId                   0
# ProductCategory             0
# ChannelId                   0
# Amount                      0
# Value                       3
# TransactionStartTime        1
# PricingStrategy             3
# FraudResult                 0
# Unnamed: 16             95646
# Unnamed: 17             95650
# dtype: int64

# %%
generate_summary_statistics(data)
# Out:
#                         count unique                   top   freq  \
# TransactionId           95662  95662   TransactionId_76871      1
# BatchId                 95662  94809         BatchId_67019     28
# AccountId               95660   3633        AccountId_4841  30893
# SubscriptionId          95662   3627   SubscriptionId_3829  32630
# CustomerId              95662   3742       CustomerId_7343   4091
# CurrencyCode            95662      1                   UGX  95662
# CountryCode           95660.0    NaN                   NaN    NaN
# ProviderId              95660      6          ProviderId_4  38189
# ProductId               95662     23           ProductId_6  32635
# ProductCategory         95662      9    financial_services  45405
# ChannelId               95662      4           ChannelId_3  56935
# Amount                95662.0    NaN                   NaN    NaN
# Value                 95659.0    NaN                   NaN    NaN
# TransactionStartTime    95661  94555  2018-12-24T16:30:13Z     17
# PricingStrategy       95659.0    NaN                   NaN    NaN
# FraudResult           95662.0    NaN                   NaN    NaN
# Unnamed: 16                16     16         January542024      1
# Unnamed: 17                12      7           202454March      4
#
#                              mean            std        min    25%     50%  \
# TransactionId                 NaN            NaN        NaN    NaN     NaN
# BatchId                       NaN            NaN        NaN    NaN     NaN
# AccountId                     NaN            NaN        NaN    NaN     NaN
# SubscriptionId                NaN            NaN        NaN    NaN     NaN
# CustomerId                    NaN            NaN        NaN    NaN     NaN
# CurrencyCode                  NaN            NaN        NaN    NaN     NaN
# CountryCode                 256.0            0.0      256.0  256.0   256.0
# ProviderId                    NaN            NaN        NaN    NaN     NaN
# ProductId                     NaN            NaN        NaN    NaN     NaN
# ProductCategory               NaN            NaN        NaN    NaN     NaN
# ChannelId                     NaN            NaN        NaN    NaN     NaN
# Amount                6718.071528  123306.788665 -1000000.0  -50.0  1000.0
# Value                  9900.64041  123124.006009        2.0  275.0  1000.0
# TransactionStartTime          NaN            NaN        NaN    NaN     NaN
# PricingStrategy          2.255899       0.732849        0.0    2.0     2.0
# FraudResult              0.002018       0.044872        0.0    0.0     0.0
# Unnamed: 16                   NaN            NaN        NaN    NaN     NaN
# Unnamed: 17                   NaN            NaN        NaN    NaN     NaN
#
#                          75%        max
# TransactionId            NaN        NaN
# BatchId                  NaN        NaN
# AccountId                NaN        NaN
# SubscriptionId           NaN        NaN
# CustomerId               NaN        NaN
# CurrencyCode             NaN        NaN
# CountryCode            256.0      256.0
# ProviderId               NaN        NaN
# ProductId                NaN        NaN
# ProductCategory          NaN        NaN
# ChannelId                NaN        NaN
# Amount                2800.0  9880000.0
# Value                 5000.0  9880000.0
# TransactionStartTime     NaN        NaN
# PricingStrategy          2.0        4.0
# FraudResult              0.0        1.0
# Unnamed: 16              NaN        NaN
# Unnamed: 17              NaN        NaN

# %%
data['Amount'].sum(), data_xlsx['Amount'].sum()
# Out:
# (642664158.5, 642664158.5)

# %%
data.shape[0] - (data['Value'] == data_xlsx['Value']).sum()
# Out:
# 3

# %%
data_xlsx.describe(), data.describe()
# Out:
# (       CountryCode        Amount         Value  PricingStrategy   FraudResult
#  count      95660.0  9.566200e+04  9.565900e+04     95659.000000  95662.000000
#  mean         256.0  6.718072e+03  9.900640e+03         2.255899      0.002018
#  std            0.0  1.233068e+05  1.231240e+05         0.732849      0.044872
#  min          256.0 -1.000000e+06  2.000000e+00         0.000000      0.000000
#  25%          256.0 -5.000000e+01  2.750000e+02         2.000000      0.000000
#  50%          256.0  1.000000e+03  1.000000e+03         2.000000      0.000000
#  75%          256.0  2.800000e+03  5.000000e+03         2.000000      0.000000
#  max          256.0  9.880000e+06  9.880000e+06         4.000000      1.000000,
#         CountryCode        Amount         Value  PricingStrategy   FraudResult
#  count      95660.0  9.566200e+04  9.565900e+04     95659.000000  95662.000000
#  mean         256.0  6.718072e+03  9.900640e+03         2.255899      0.002018
#  std            0.0  1.233068e+05  1.231240e+05         0.732849      0.044872
#  min          256.0 -1.000000e+06  2.000000e+00         0.000000      0.000000
#  25%          256.0 -5.000000e+01  2.750000e+02         2.000000      0.000000
#  50%          256.0  1.000000e+03  1.000000e+03         2.000000      0.000000
#  75%          256.0  2.800000e+03  5.000000e+03         2.000000      0.000000
#  max          256.0  9.880000e+06  9.880000e+06         4.000000      1.000000)

# %%
data['Value'].sum() - data_xlsx['Value'].sum()
# Out:
# 0.0

# %%
# Plot Numerical Distributions
numerical_columns = ['Amount', 'Value', 'PricingStrategy']
plot_numerical_distributions(data, numerical_columns, plot_output_dir)
# Out:
# 2025-01-26 10:49:12 - INFO - Distribution plot saved for Amount at ..\screenshots\plots/Amount_distribution.png
# 2025-01-26 10:49:12 - INFO - Distribution plot saved for Amount at ..\screenshots\plots/Amount_distribution.png
# 2025-01-26 10:49:12 - INFO - Distribution plot saved for Amount at ..\screenshots\plots/Amount_distribution.png
# 2025-01-26 10:49:12 - INFO - Distribution plot saved for Amount at ..\screenshots\plots/Amount_distribution.png
# 2025-01-26 10:49:12 - INFO - Distribution plot saved for Amount at ..\screenshots\plots/Amount_distribution.png
# c:\Users\Darkles\10academy\10Academy-Kifiya-Week-6\notebooks\..\scripts\utils\visualization.py:51: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# 2025-01-26 10:49:13 - INFO - Distribution plot saved for Value at ..\screenshots\plots/Value_distribution.png
# 2025-01-26 10:49:13 - INFO - Distribution plot saved for Value at ..\screenshots\plots/Value_distribution.png
# 2025-01-26 10:49:13 - INFO - Distribution plot saved for Value at ..\screenshots\plots/Value_distribution.png
# 2025-01-26 10:49:13 - INFO - Distribution plot saved for Value at ..\screenshots\plots/Value_distribution.png
# 2025-01-26 10:49:13 - INFO - Distribution plot saved for Value at ..\screenshots\plots/Value_distribution.png
# c:\Users\Darkles\10academy\10Academy-Kifiya-Week-6\notebooks\..\scripts\utils\visualization.py:51: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# 2025-01-26 10:49:15 - INFO - Distribution plot saved for PricingStrategy at ..\screenshots\plots/PricingStrategy_distribution.png
# 2025-01-26 10:49:15 - INFO - Distribution plot saved for PricingStrategy at ..\screenshots\plots/PricingStrategy_distribution.png
# 2025-01-26 10:49:15 - INFO - Distribution plot saved for PricingStrategy at ..\screenshots\plots/PricingStrategy_distribution.png
# 2025-01-26 10:49:15 - INFO - Distribution plot saved for PricingStrategy at ..\screenshots\plots/PricingStrategy_distribution.png
# 2025-01-26 10:49:15 - INFO - Distribution plot saved for PricingStrategy at ..\screenshots\plots/PricingStrategy_distribution.png
# c:\Users\Darkles\10academy\10Academy-Kifiya-Week-6\notebooks\..\scripts\utils\visualization.py:51: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# Plot Categorical Distributions
categorical_columns = ["CurrencyCode", "ProductCategory", "ChannelId", "ProviderId"]
plot_categorical_distributions(data, categorical_columns, plot_output_dir)
# Out:
# c:\Users\Darkles\10academy\10Academy-Kifiya-Week-6\notebooks\..\scripts\utils\visualization.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=col, data=data, order=data[col].value_counts().index, palette="viridis")
# 2025-01-26 10:49:16 - INFO - Distribution plot saved for CurrencyCode at ..\screenshots\plots/CurrencyCode_distribution.png
# 2025-01-26 10:49:16 - INFO - Distribution plot saved for CurrencyCode at ..\screenshots\plots/CurrencyCode_distribution.png
# 2025-01-26 10:49:16 - INFO - Distribution plot saved for CurrencyCode at ..\screenshots\plots/CurrencyCode_distribution.png
# 2025-01-26 10:49:16 - INFO - Distribution plot saved for CurrencyCode at ..\screenshots\plots/CurrencyCode_distribution.png
# 2025-01-26 10:49:16 - INFO - Distribution plot saved for CurrencyCode at ..\screenshots\plots/CurrencyCode_distribution.png
# c:\Users\Darkles\10academy\10Academy-Kifiya-Week-6\notebooks\..\scripts\utils\visualization.py:65: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# c:\Users\Darkles\10academy\10Academy-Kifiya-Week-6\notebooks\..\scripts\utils\visualization.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=col, data=data, order=data[col].value_counts().index, palette="viridis")
# 2025-01-26 10:49:16 - INFO - Distribution plot saved for ProductCategory at ..\screenshots\plots/ProductCategory_distribution.png
# 2025-01-26 10:49:16 - INFO - Distribution plot saved for ProductCategory at ..\screenshots\plots/ProductCategory_distribution.png
# 2025-01-26 10:49:16 - INFO - Distribution plot saved for ProductCategory at ..\screenshots\plots/ProductCategory_distribution.png
# 2025-01-26 10:49:16 - INFO - Distribution plot saved for ProductCategory at ..\screenshots\plots/ProductCategory_distribution.png
# 2025-01-26 10:49:16 - INFO - Distribution plot saved for ProductCategory at ..\screenshots\plots/ProductCategory_distribution.png
# c:\Users\Darkles\10academy\10Academy-Kifiya-Week-6\notebooks\..\scripts\utils\visualization.py:65: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# c:\Users\Darkles\10academy\10Academy-Kifiya-Week-6\notebooks\..\scripts\utils\visualization.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=col, data=data, order=data[col].value_counts().index, palette="viridis")
# 2025-01-26 10:49:17 - INFO - Distribution plot saved for ChannelId at ..\screenshots\plots/ChannelId_distribution.png
# 2025-01-26 10:49:17 - INFO - Distribution plot saved for ChannelId at ..\screenshots\plots/ChannelId_distribution.png
# 2025-01-26 10:49:17 - INFO - Distribution plot saved for ChannelId at ..\screenshots\plots/ChannelId_distribution.png
# 2025-01-26 10:49:17 - INFO - Distribution plot saved for ChannelId at ..\screenshots\plots/ChannelId_distribution.png
# 2025-01-26 10:49:17 - INFO - Distribution plot saved for ChannelId at ..\screenshots\plots/ChannelId_distribution.png
# c:\Users\Darkles\10academy\10Academy-Kifiya-Week-6\notebooks\..\scripts\utils\visualization.py:65: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# c:\Users\Darkles\10academy\10Academy-Kifiya-Week-6\notebooks\..\scripts\utils\visualization.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=col, data=data, order=data[col].value_counts().index, palette="viridis")
# 2025-01-26 10:49:17 - INFO - Distribution plot saved for ProviderId at ..\screenshots\plots/ProviderId_distribution.png
# 2025-01-26 10:49:17 - INFO - Distribution plot saved for ProviderId at ..\screenshots\plots/ProviderId_distribution.png
# 2025-01-26 10:49:17 - INFO - Distribution plot saved for ProviderId at ..\screenshots\plots/ProviderId_distribution.png
# 2025-01-26 10:49:17 - INFO - Distribution plot saved for ProviderId at ..\screenshots\plots/ProviderId_distribution.png
# 2025-01-26 10:49:17 - INFO - Distribution plot saved for ProviderId at ..\screenshots\plots/ProviderId_distribution.png
# c:\Users\Darkles\10academy\10Academy-Kifiya-Week-6\notebooks\..\scripts\utils\visualization.py:65: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# Plot Correlation Matrix
plot_correlation_matrix(data, plot_output_dir)
# Out:
# 2025-01-26 10:49:18 - INFO - Correlation matrix saved to ..\screenshots\plots\missing_values_plot.png
# 2025-01-26 10:49:18 - INFO - Correlation matrix saved to ..\screenshots\plots\missing_values_plot.png
# 2025-01-26 10:49:18 - INFO - Correlation matrix saved to ..\screenshots\plots\missing_values_plot.png
# 2025-01-26 10:49:18 - INFO - Correlation matrix saved to ..\screenshots\plots\missing_values_plot.png
# 2025-01-26 10:49:18 - INFO - Correlation matrix saved to ..\screenshots\plots\missing_values_plot.png
# c:\Users\Darkles\10academy\10Academy-Kifiya-Week-6\notebooks\..\scripts\utils\visualization.py:80: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# Visualize and save missing values plot
visualize_missing_values(data, output_dir=plot_output_dir)
# Out:
# c:\Users\Darkles\10academy\10Academy-Kifiya-Week-6\notebooks\..\scripts\utils\visualization.py:87: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=missing_values.values, y=missing_values.index, palette="viridis")
# 2025-01-26 10:49:19 - INFO - Missing values plot saved to ..\screenshots\plots\missing_values_plot.png
# 2025-01-26 10:49:19 - INFO - Missing values plot saved to ..\screenshots\plots\missing_values_plot.png
# 2025-01-26 10:49:19 - INFO - Missing values plot saved to ..\screenshots\plots\missing_values_plot.png
# 2025-01-26 10:49:19 - INFO - Missing values plot saved to ..\screenshots\plots\missing_values_plot.png
# 2025-01-26 10:49:19 - INFO - Missing values plot saved to ..\screenshots\plots\missing_values_plot.png
# c:\Users\Darkles\10academy\10Academy-Kifiya-Week-6\notebooks\..\scripts\utils\visualization.py:99: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# Analyze missing values and save CSV
missing_values_output_path = os.path.join(DATAPATH, 'processed', 'missing_values.csv')
missing_summary_enhanced = analyze_missing_values(data, output_path=missing_values_output_path)
# display(missing_summary_enhanced)
missing_summary_enhanced
# Out:
# 2025-01-26 10:49:19 - INFO - Missing value analysis completed.
# 2025-01-26 10:49:19 - INFO - Missing value analysis completed.
# 2025-01-26 10:49:19 - INFO - Missing value analysis completed.
# 2025-01-26 10:49:19 - INFO - Missing value analysis completed.
# 2025-01-26 10:49:19 - INFO - Missing value analysis completed.
# 2025-01-26 10:49:19 - INFO - Missing values analysis saved to ..\resources\data\processed\missing_values.csv
# 2025-01-26 10:49:19 - INFO - Missing values analysis saved to ..\resources\data\processed\missing_values.csv
# 2025-01-26 10:49:19 - INFO - Missing values analysis saved to ..\resources\data\processed\missing_values.csv
# 2025-01-26 10:49:19 - INFO - Missing values analysis saved to ..\resources\data\processed\missing_values.csv
# 2025-01-26 10:49:19 - INFO - Missing values analysis saved to ..\resources\data\processed\missing_values.csv
#                   Column  MissingCount  MissingPercentage
# 2              AccountId             2           0.002091
# 6            CountryCode             2           0.002091
# 7             ProviderId             2           0.002091
# 12                 Value             3           0.003136
# 13  TransactionStartTime             1           0.001045
# 14       PricingStrategy             3           0.003136
# 16           Unnamed: 16         95646          99.983274
# 17           Unnamed: 17         95650          99.987456

# %%
# Detect outliers and save boxplots
numerical_columns = ['Amount', 'Value', 'PricingStrategy']
detect_outliers(data, numerical_columns=numerical_columns, output_dir=plot_output_dir)
# Out:
# 2025-01-26 10:49:21 - INFO - Outlier detection plot for column Amount saved to ..\screenshots\plots\Amount_boxplot.png
# 2025-01-26 10:49:21 - INFO - Outlier detection plot for column Amount saved to ..\screenshots\plots\Amount_boxplot.png
# 2025-01-26 10:49:21 - INFO - Outlier detection plot for column Amount saved to ..\screenshots\plots\Amount_boxplot.png
# 2025-01-26 10:49:21 - INFO - Outlier detection plot for column Amount saved to ..\screenshots\plots\Amount_boxplot.png
# 2025-01-26 10:49:21 - INFO - Outlier detection plot for column Amount saved to ..\screenshots\plots\Amount_boxplot.png
# c:\Users\Darkles\10academy\10Academy-Kifiya-Week-6\notebooks\..\scripts\utils\visualization.py:116: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# 2025-01-26 10:49:21 - INFO - Outlier detection plot for column Value saved to ..\screenshots\plots\Value_boxplot.png
# 2025-01-26 10:49:21 - INFO - Outlier detection plot for column Value saved to ..\screenshots\plots\Value_boxplot.png
# 2025-01-26 10:49:21 - INFO - Outlier detection plot for column Value saved to ..\screenshots\plots\Value_boxplot.png
# 2025-01-26 10:49:21 - INFO - Outlier detection plot for column Value saved to ..\screenshots\plots\Value_boxplot.png
# 2025-01-26 10:49:21 - INFO - Outlier detection plot for column Value saved to ..\screenshots\plots\Value_boxplot.png
# c:\Users\Darkles\10academy\10Academy-Kifiya-Week-6\notebooks\..\scripts\utils\visualization.py:116: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# 2025-01-26 10:49:22 - INFO - Outlier detection plot for column PricingStrategy saved to ..\screenshots\plots\PricingStrategy_boxplot.png
# 2025-01-26 10:49:22 - INFO - Outlier detection plot for column PricingStrategy saved to ..\screenshots\plots\PricingStrategy_boxplot.png
# 2025-01-26 10:49:22 - INFO - Outlier detection plot for column PricingStrategy saved to ..\screenshots\plots\PricingStrategy_boxplot.png
# 2025-01-26 10:49:22 - INFO - Outlier detection plot for column PricingStrategy saved to ..\screenshots\plots\PricingStrategy_boxplot.png
# 2025-01-26 10:49:22 - INFO - Outlier detection plot for column PricingStrategy saved to ..\screenshots\plots\PricingStrategy_boxplot.png
# c:\Users\Darkles\10academy\10Academy-Kifiya-Week-6\notebooks\..\scripts\utils\visualization.py:116: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# plot_boxplot(data, 'ProductCategory', 'PricingStrategy', title='', xlabel='', ylabel='', palette='pastel')
# plot_scatterplot(data, 'ProductCategory', 'PricingStrategy', title='', xlabel='', ylabel='', hue='ProductCategory', palette='Set1')
# plot_histogram(data, 'ProductCategory', title='', xlabel='', ylabel='', kde=True, bins=20, color='blue')
# plot_pairplot(data, hue='ProductCategory')

# %% [markdown]
# # Preprocessed

# %%
filename = "processed"
irrelevant_columns = ['Unnamed: 16', 'Unnamed: 17']
numerical_columns = ['Amount', 'Value', 'PricingStrategy']
categorical_columns = ["CurrencyCode", "ProductCategory", "ChannelId", "ProviderId"]
date_column = "TransactionStartTime"

missing_value_strategies = {
        "CountryCode": "most_frequent",
        "AccountId": "most_frequent",
        "ProviderId": "most_frequent",
        "PricingStrategy": "median",
        "Value": "mean",
}
dtype_conversions = {
        "CountryCode": "int64",
}

data = data_xlsx

preprocessed_data = preprocess_data(data, irrelevant_columns, categorical_columns, numerical_columns, 
                                    missing_value_strategies, date_column, dtype_conversions, filename, processed_output_dir)
preprocessed_data
# Out:
# 2025-01-26 10:49:23 - INFO - Cleaning...
# 2025-01-26 10:49:23 - INFO - Cleaning...
# 2025-01-26 10:49:23 - INFO - Cleaning...
# 2025-01-26 10:49:23 - INFO - Cleaning...
# 2025-01-26 10:49:23 - INFO - Cleaning...
# 2025-01-26 10:49:23 - INFO - Dropped columns: {'Unnamed: 17', 'Unnamed: 16'}. Remaining columns: ['TransactionId', 'BatchId', 'AccountId', 'SubscriptionId', 'CustomerId', 'CurrencyCode', 'CountryCode', 'ProviderId', 'ProductId', 'ProductCategory', 'ChannelId', 'Amount', 'Value', 'TransactionStartTime', 'PricingStrategy', 'FraudResult']
# 2025-01-26 10:49:23 - INFO - Dropped columns: {'Unnamed: 17', 'Unnamed: 16'}. Remaining columns: ['TransactionId', 'BatchId', 'AccountId', 'SubscriptionId', 'CustomerId', 'CurrencyCode', 'CountryCode', 'ProviderId', 'ProductId', 'ProductCategory', 'ChannelId', 'Amount', 'Value', 'TransactionStartTime', 'PricingStrategy', 'FraudResult']
# 2025-01-26 10:49:23 - INFO - Dropped columns: {'Unnamed: 17', 'Unnamed: 16'}. Remaining columns: ['TransactionId', 'BatchId', 'AccountId', 'SubscriptionId', 'CustomerId', 'CurrencyCode', 'CountryCode', 'ProviderId', 'ProductId', 'ProductCategory', 'ChannelId', 'Amount', 'Value', 'TransactionStartTime', 'PricingStrategy', 'FraudResult']
# 2025-01-26 10:49:23 - INFO - Dropped columns: {'Unnamed: 17', 'Unnamed: 16'}. Remaining columns: ['TransactionId', 'BatchId', 'AccountId', 'SubscriptionId', 'CustomerId', 'CurrencyCode', 'CountryCode', 'ProviderId', 'ProductId', 'ProductCategory', 'ChannelId', 'Amount', 'Value', 'TransactionStartTime', 'PricingStrategy', 'FraudResult']
# 2025-01-26 10:49:23 - INFO - Dropped columns: {'Unnamed: 17', 'Unnamed: 16'}. Remaining columns: ['TransactionId', 'BatchId', 'AccountId', 'SubscriptionId', 'CustomerId', 'CurrencyCode', 'CountryCode', 'ProviderId', 'ProductId', 'ProductCategory', 'ChannelId', 'Amount', 'Value', 'TransactionStartTime', 'PricingStrategy', 'FraudResult']
# 2025-01-26 10:49:23 - INFO - Imputed missing values in CountryCode using strategy: most_frequent
# 2025-01-26 10:49:23 - INFO - Imputed missing values in CountryCode using strategy: most_frequent
# 2025-01-26 10:49:23 - INFO - Imputed missing values in CountryCode using strategy: most_frequent
# 2025-01-26 10:49:23 - INFO - Imputed missing values in CountryCode using strategy: most_frequent
# 2025-01-26 10:49:23 - INFO - Imputed missing values in CountryCode using strategy: most_frequent
# 2025-01-26 10:49:23 - INFO - Imputed missing values in AccountId using strategy: most_frequent
# 2025-01-26 10:49:23 - INFO - Imputed missing values in AccountId using strategy: most_frequent
# 2025-01-26 10:49:23 - INFO - Imputed missing values in AccountId using strategy: most_frequent
# 2025-01-26 10:49:23 - INFO - Imputed missing values in AccountId using strategy: most_frequent
# 2025-01-26 10:49:23 - INFO - Imputed missing values in AccountId using strategy: most_frequent
# 2025-01-26 10:49:23 - INFO - Imputed missing values in ProviderId using strategy: most_frequent
# 2025-01-26 10:49:23 - INFO - Imputed missing values in ProviderId using strategy: most_frequent
# 2025-01-26 10:49:23 - INFO - Imputed missing values in ProviderId using strategy: most_frequent
# 2025-01-26 10:49:23 - INFO - Imputed missing values in ProviderId using strategy: most_frequent
# 2025-01-26 10:49:23 - INFO - Imputed missing values in ProviderId using strategy: most_frequent
# 2025-01-26 10:49:23 - INFO - Imputed missing values in PricingStrategy using strategy: median
# 2025-01-26 10:49:23 - INFO - Imputed missing values in PricingStrategy using strategy: median
# 2025-01-26 10:49:23 - INFO - Imputed missing values in PricingStrategy using strategy: median
# 2025-01-26 10:49:23 - INFO - Imputed missing values in PricingStrategy using strategy: median
# 2025-01-26 10:49:23 - INFO - Imputed missing values in PricingStrategy using strategy: median
# 2025-01-26 10:49:23 - INFO - Imputed missing values in Value using strategy: mean
# 2025-01-26 10:49:23 - INFO - Imputed missing values in Value using strategy: mean
# 2025-01-26 10:49:23 - INFO - Imputed missing values in Value using strategy: mean
# 2025-01-26 10:49:23 - INFO - Imputed missing values in Value using strategy: mean
# 2025-01-26 10:49:23 - INFO - Imputed missing values in Value using strategy: mean
# 2025-01-26 10:49:23 - INFO - Removed 0 duplicate rows.
# 2025-01-26 10:49:23 - INFO - Removed 0 duplicate rows.
# 2025-01-26 10:49:23 - INFO - Removed 0 duplicate rows.
# 2025-01-26 10:49:23 - INFO - Removed 0 duplicate rows.
# 2025-01-26 10:49:23 - INFO - Removed 0 duplicate rows.
# 2025-01-26 10:49:24 - INFO - Converted column CountryCode to int64
# 2025-01-26 10:49:24 - INFO - Converted column CountryCode to int64
# 2025-01-26 10:49:24 - INFO - Converted column CountryCode to int64
# 2025-01-26 10:49:24 - INFO - Converted column CountryCode to int64
# 2025-01-26 10:49:24 - INFO - Converted column CountryCode to int64
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: CurrencyCode
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: CurrencyCode
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: CurrencyCode
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: CurrencyCode
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: CurrencyCode
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: ProductCategory
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: ProductCategory
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: ProductCategory
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: ProductCategory
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: ProductCategory
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: ChannelId
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: ChannelId
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: ChannelId
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: ChannelId
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: ChannelId
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: ProviderId
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: ProviderId
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: ProviderId
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: ProviderId
# 2025-01-26 10:49:24 - INFO - Standardized categorical column: ProviderId
# 2025-01-26 10:49:24 - INFO - Data cleaning pipeline executed successfully.
# 2025-01-26 10:49:24 - INFO - Data cleaning pipeline executed successfully.
# 2025-01-26 10:49:24 - INFO - Data cleaning pipeline executed successfully.
# 2025-01-26 10:49:24 - INFO - Data cleaning pipeline executed successfully.
# 2025-01-26 10:49:24 - INFO - Data cleaning pipeline executed successfully.
# 2025-01-26 10:49:24 - INFO - Saving preprocessed data...
# 2025-01-26 10:49:24 - INFO - Saving preprocessed data...
# 2025-01-26 10:49:24 - INFO - Saving preprocessed data...
# 2025-01-26 10:49:24 - INFO - Saving preprocessed data...
# 2025-01-26 10:49:24 - INFO - Saving preprocessed data...
# 2025-01-26 10:49:26 - INFO - Data saved to ..\resources\data\processed\processed.csv
# 2025-01-26 10:49:26 - INFO - Data saved to ..\resources\data\processed\processed.csv
# 2025-01-26 10:49:26 - INFO - Data saved to ..\resources\data\processed\processed.csv
# 2025-01-26 10:49:26 - INFO - Data saved to ..\resources\data\processed\processed.csv
# 2025-01-26 10:49:26 - INFO - Data saved to ..\resources\data\processed\processed.csv
# 2025-01-26 10:49:28 - INFO - Data saved to ..\resources\data\processed\processed.json
# 2025-01-26 10:49:28 - INFO - Data saved to ..\resources\data\processed\processed.json
# 2025-01-26 10:49:28 - INFO - Data saved to ..\resources\data\processed\processed.json
# 2025-01-26 10:49:28 - INFO - Data saved to ..\resources\data\processed\processed.json
# 2025-01-26 10:49:28 - INFO - Data saved to ..\resources\data\processed\processed.json
# 2025-01-26 10:49:28 - INFO - Preprocessed data saved to ..\resources\data\processed
# 2025-01-26 10:49:28 - INFO - Preprocessed data saved to ..\resources\data\processed
# 2025-01-26 10:49:28 - INFO - Preprocessed data saved to ..\resources\data\processed
# 2025-01-26 10:49:28 - INFO - Preprocessed data saved to ..\resources\data\processed
# 2025-01-26 10:49:28 - INFO - Preprocessed data saved to ..\resources\data\processed
#               TransactionId         BatchId       AccountId  \
# 0       TransactionId_76871   BatchId_36123  AccountId_3957
# 1       TransactionId_73770   BatchId_15642  AccountId_4841
# 2       TransactionId_26203   BatchId_53941  AccountId_4229
# 3         TransactionId_380  BatchId_102363   AccountId_648
# 4       TransactionId_28195   BatchId_38780  AccountId_4841
# ...                     ...             ...             ...
# 95656   TransactionId_89881   BatchId_96668  AccountId_4841
# 95657   TransactionId_91597    BatchId_3503  AccountId_3439
# 95658   TransactionId_82501  BatchId_118602  AccountId_4841
# 95659  TransactionId_136354   BatchId_70924  AccountId_1346
# 95660   TransactionId_35670   BatchId_29317  AccountId_4841
#
#             SubscriptionId       CustomerId CurrencyCode  CountryCode  \
# 0       SubscriptionId_887  CustomerId_4406          UGX          256
# 1      SubscriptionId_3829  CustomerId_4406          UGX          256
# 2       SubscriptionId_222  CustomerId_4683          UGX          256
# 3      SubscriptionId_2185   CustomerId_988          UGX          256
# 4      SubscriptionId_3829   CustomerId_988          UGX          256
# ...                    ...              ...          ...          ...
# 95656  SubscriptionId_3829  CustomerId_3078          UGX          256
# 95657  SubscriptionId_2643  CustomerId_3874          UGX          256
# 95658  SubscriptionId_3829  CustomerId_3874          UGX          256
# 95659   SubscriptionId_652  CustomerId_1709          UGX          256
# 95660  SubscriptionId_3829  CustomerId_1709          UGX          256
#
#          ProviderId     ProductId     ProductCategory    ChannelId   Amount  \
# 0      PROVIDERID_6  ProductId_10             AIRTIME  CHANNELID_3   1000.0
# 1      PROVIDERID_4   ProductId_6  FINANCIAL_SERVICES  CHANNELID_2   3679.0
# 2      PROVIDERID_4   ProductId_1             AIRTIME  CHANNELID_3    500.0
# 3      PROVIDERID_1  ProductId_21        UTILITY_BILL  CHANNELID_3  20000.0
# 4      PROVIDERID_4   ProductId_6  FINANCIAL_SERVICES  CHANNELID_2   -644.0
# ...             ...           ...                 ...          ...      ...
# 95656  PROVIDERID_4   ProductId_6  FINANCIAL_SERVICES  CHANNELID_2  -1000.0
# 95657  PROVIDERID_6  ProductId_10             AIRTIME  CHANNELID_3   1000.0
# 95658  PROVIDERID_4   ProductId_6  FINANCIAL_SERVICES  CHANNELID_2    -20.0
# 95659  PROVIDERID_6  ProductId_19                  TV  CHANNELID_3   3000.0
# 95660  PROVIDERID_4   ProductId_6  FINANCIAL_SERVICES  CHANNELID_2    -60.0
#
#             Value      TransactionStartTime  PricingStrategy  FraudResult
# 0      1000.00000 2018-11-15 02:18:49+00:00              2.0            0
# 1        20.00000 2018-11-15 02:19:08+00:00              2.0            0
# 2       500.00000 2018-11-15 02:44:21+00:00              2.0            0
# 3      9900.64041 2018-11-15 03:32:55+00:00              2.0            0
# 4       644.00000 2018-11-15 03:34:21+00:00              2.0            0
# ...           ...                       ...              ...          ...
# 95656  1000.00000 2019-02-13 09:54:09+00:00              2.0            0
# 95657  1000.00000 2019-02-13 09:54:25+00:00              2.0            0
# 95658    20.00000 2019-02-13 09:54:35+00:00              2.0            0
# 95659  3000.00000 2019-02-13 10:01:10+00:00              2.0            0
# 95660    60.00000 2019-02-13 10:01:28+00:00              2.0            0
#
# [95661 rows x 16 columns]

# %% [markdown]
# # Feature Engineerign

# %%
feature_output_dir = os.path.join(DATAPATH, 'features')
os.makedirs(feature_output_dir, exist_ok=True)

aggregated_features_path = os.path.join(feature_output_dir, "aggregate_features.csv")
temporal_features_path = os.path.join(feature_output_dir, "temporal_features.csv")
encoded_features_path = os.path.join(feature_output_dir, "encoded_features.csv")
missing_handled_path = os.path.join(feature_output_dir, "missing_handled.csv")
normalized_features_path = os.path.join(feature_output_dir, "normalized_features.csv")
data = preprocessed_data

# %%
# Aggregate Features
data_aggregated = create_aggregate_features(data, output_path=aggregated_features_path)
data = data_aggregated
# Out:
# 2025-01-26 10:49:28 - INFO - Creating aggregate features.
# 2025-01-26 10:49:28 - INFO - Creating aggregate features.
# 2025-01-26 10:49:28 - INFO - Creating aggregate features.
# 2025-01-26 10:49:28 - INFO - Creating aggregate features.
# 2025-01-26 10:49:28 - INFO - Creating aggregate features.
# 2025-01-26 10:49:28 - INFO - Aggregate features created successfully.
# 2025-01-26 10:49:28 - INFO - Aggregate features created successfully.
# 2025-01-26 10:49:28 - INFO - Aggregate features created successfully.
# 2025-01-26 10:49:28 - INFO - Aggregate features created successfully.
# 2025-01-26 10:49:28 - INFO - Aggregate features created successfully.
# 2025-01-26 10:49:28 - INFO - Aggregate features saved to ..\resources\data\features\aggregate_features.csv
# 2025-01-26 10:49:28 - INFO - Aggregate features saved to ..\resources\data\features\aggregate_features.csv
# 2025-01-26 10:49:28 - INFO - Aggregate features saved to ..\resources\data\features\aggregate_features.csv
# 2025-01-26 10:49:28 - INFO - Aggregate features saved to ..\resources\data\features\aggregate_features.csv
# 2025-01-26 10:49:28 - INFO - Aggregate features saved to ..\resources\data\features\aggregate_features.csv
# 2025-01-26 10:49:28 - INFO - Aggregate features created and merged into the dataframe.
# 2025-01-26 10:49:28 - INFO - Aggregate features created and merged into the dataframe.
# 2025-01-26 10:49:28 - INFO - Aggregate features created and merged into the dataframe.
# 2025-01-26 10:49:28 - INFO - Aggregate features created and merged into the dataframe.
# 2025-01-26 10:49:28 - INFO - Aggregate features created and merged into the dataframe.

# %%
# Temporal Features
date_column = 'TransactionStartTime'
data_temporal = extract_temporal_features(data, date_column, output_path=temporal_features_path)
data =data_temporal
# Out:
# 2025-01-26 10:50:30 - INFO - Extracting datetime features.
# 2025-01-26 10:50:30 - INFO - Extracting datetime features.
# 2025-01-26 10:50:30 - INFO - Extracting datetime features.
# 2025-01-26 10:50:30 - INFO - Extracting datetime features.
# 2025-01-26 10:50:30 - INFO - Extracting datetime features.
# 2025-01-26 10:50:30 - INFO - Temporal features extracted.
# 2025-01-26 10:50:30 - INFO - Temporal features extracted.
# 2025-01-26 10:50:30 - INFO - Temporal features extracted.
# 2025-01-26 10:50:30 - INFO - Temporal features extracted.
# 2025-01-26 10:50:30 - INFO - Temporal features extracted.
# 2025-01-26 10:50:34 - INFO - Datetime features saved to ..\resources\data\features\temporal_features.csv
# 2025-01-26 10:50:34 - INFO - Datetime features saved to ..\resources\data\features\temporal_features.csv
# 2025-01-26 10:50:34 - INFO - Datetime features saved to ..\resources\data\features\temporal_features.csv
# 2025-01-26 10:50:34 - INFO - Datetime features saved to ..\resources\data\features\temporal_features.csv
# 2025-01-26 10:50:34 - INFO - Datetime features saved to ..\resources\data\features\temporal_features.csv

# %%
# Encode Categorical Variables
# Specify columns for one-hot and label encoding
one_hot_columns = ["ProductCategory", "ChannelId"]
label_columns = ["CurrencyCode", "CountryCode"] #, "ProviderId"]
data_encoded, encoder_map = encode_categorical_variables(data, one_hot_columns, label_columns, output_path=encoded_features_path)
data = data_encoded
# Out:
# 2025-01-26 10:50:37 - INFO - Performing One-Hot Encoding.
# 2025-01-26 10:50:37 - INFO - Performing One-Hot Encoding.
# 2025-01-26 10:50:37 - INFO - Performing One-Hot Encoding.
# 2025-01-26 10:50:37 - INFO - Performing One-Hot Encoding.
# 2025-01-26 10:50:37 - INFO - Performing One-Hot Encoding.
# 2025-01-26 10:50:38 - INFO - Performing Label Encoding.
# 2025-01-26 10:50:38 - INFO - Performing Label Encoding.
# 2025-01-26 10:50:38 - INFO - Performing Label Encoding.
# 2025-01-26 10:50:38 - INFO - Performing Label Encoding.
# 2025-01-26 10:50:38 - INFO - Performing Label Encoding.
# 2025-01-26 10:50:43 - INFO - Encoded features saved to ..\resources\data\features\encoded_features.csv
# 2025-01-26 10:50:43 - INFO - Encoded features saved to ..\resources\data\features\encoded_features.csv
# 2025-01-26 10:50:43 - INFO - Encoded features saved to ..\resources\data\features\encoded_features.csv
# 2025-01-26 10:50:43 - INFO - Encoded features saved to ..\resources\data\features\encoded_features.csv
# 2025-01-26 10:50:43 - INFO - Encoded features saved to ..\resources\data\features\encoded_features.csv
# 2025-01-26 10:50:43 - INFO - Categorical variables encoded successfully.
# 2025-01-26 10:50:43 - INFO - Categorical variables encoded successfully.
# 2025-01-26 10:50:43 - INFO - Categorical variables encoded successfully.
# 2025-01-26 10:50:43 - INFO - Categorical variables encoded successfully.
# 2025-01-26 10:50:43 - INFO - Categorical variables encoded successfully.

# %%
encoder_map
# Out:
# {'CurrencyCode': ['UGX'], 'CountryCode': ['256']}

# %%
# Normalize Numerical Features
numerical_features = ['total_transaction_amount', 'avg_transaction_amount', 'std_transaction_amount', 'transaction_count']
numerical_columns = ['Amount', 'Value', 'PricingStrategy'] + numerical_features
data_scaled = normalize_or_standardize(data, numerical_columns, mode='standard', output_path=normalized_features_path) # mode="normalize"
data = data_scaled
# Out:
# 2025-01-26 10:50:43 - INFO - Scaling numerical features using standard method.
# 2025-01-26 10:50:43 - INFO - Scaling numerical features using standard method.
# 2025-01-26 10:50:43 - INFO - Scaling numerical features using standard method.
# 2025-01-26 10:50:43 - INFO - Scaling numerical features using standard method.
# 2025-01-26 10:50:43 - INFO - Scaling numerical features using standard method.
# 2025-01-26 10:50:43 - INFO - Numerical features scaled using standard mode.
# 2025-01-26 10:50:43 - INFO - Numerical features scaled using standard mode.
# 2025-01-26 10:50:43 - INFO - Numerical features scaled using standard mode.
# 2025-01-26 10:50:43 - INFO - Numerical features scaled using standard mode.
# 2025-01-26 10:50:43 - INFO - Numerical features scaled using standard mode.
# 2025-01-26 10:50:47 - INFO - Scaled numerical features saved to ..\resources\data\features\normalized_features.csv
# 2025-01-26 10:50:47 - INFO - Scaled numerical features saved to ..\resources\data\features\normalized_features.csv
# 2025-01-26 10:50:47 - INFO - Scaled numerical features saved to ..\resources\data\features\normalized_features.csv
# 2025-01-26 10:50:47 - INFO - Scaled numerical features saved to ..\resources\data\features\normalized_features.csv
# 2025-01-26 10:50:47 - INFO - Scaled numerical features saved to ..\resources\data\features\normalized_features.csv
